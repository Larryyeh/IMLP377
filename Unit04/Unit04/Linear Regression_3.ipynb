# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 3. Nonlinear
#
# $$f(x) = \sin(3.2x) + 0.8x$$

# %% [markdown]
# ### 3. 生成假資料

# %%
x = np.linspace(0, 5, 100)
y = np.sin(3.2*x) + 0.8*x + 0.3*np.random.randn(100)

# %%
plt.scatter(x,y)

# %% [markdown]
# #### nonlinear

# %%
regr_lin = LinearRegression()

# %%
X = x.reshape(-1, 1)
print(X.shape)
# Out:
# (100, 1)

# %%
regr_lin.fit(X,y)
# Out:
# LinearRegression()

# %%
Y=regr_lin.predict(X)
plt.scatter(x,y)
plt.plot(x,Y , color='r')
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.5219143717405857

# %% [markdown]
# 果然超級不準, 該如何是好?

# %% [markdown]
# #### 多項式
#
# 多項式5次方

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+w_{2}x_{1}^{2}+w_{3}x_{1}^{3}+w_{4}x_{1}^{4}+w_{5}x_{1}^{5}+b$$

# %%
print(x.shape)
# Out:
# (100,)

# %%
X_poly = np.array([[k, k**2, k**3, k**4, k**5] for k in x])  # add k**6 to try it
print(X_poly.shape)
# Out:
# (100, 5)

# %%
X_poly
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [5.05050505e-02, 2.55076013e-03, 1.28826269e-04, 6.50637722e-06,
#         3.28604910e-07],
#        [1.01010101e-01, 1.02030405e-02, 1.03061015e-03, 1.04102036e-04,
#         1.05153571e-05],
#        [1.51515152e-01, 2.29568411e-02, 3.47830926e-03, 5.27016555e-04,
#         7.98509932e-05],
#        [2.02020202e-01, 4.08121620e-02, 8.24488122e-03, 1.66563257e-03,
#         3.36491428e-04],
#        [2.52525253e-01, 6.37690032e-02, 1.61032836e-02, 4.06648576e-03,
#         1.02689034e-03],
#        [3.03030303e-01, 9.18273646e-02, 2.78264741e-02, 8.43226488e-03,
#         2.55523178e-03],
#        [3.53535354e-01, 1.24987246e-01, 4.41874103e-02, 1.56218117e-02,
#         5.52286273e-03],
#        [4.04040404e-01, 1.63248648e-01, 6.59590497e-02, 2.66501211e-02,
#         1.07677257e-02],
#        [4.54545455e-01, 2.06611570e-01, 9.39143501e-02, 4.26883410e-02,
#         1.94037913e-02],
#        [5.05050505e-01, 2.55076013e-01, 1.28826269e-01, 6.50637722e-02,
#         3.28604910e-02],
#        [5.55555556e-01, 3.08641975e-01, 1.71467764e-01, 9.52598689e-02,
#         5.29221494e-02],
#        [6.06060606e-01, 3.67309458e-01, 2.22611793e-01, 1.34916238e-01,
#         8.17674170e-02],
#        [6.56565657e-01, 4.31078461e-01, 2.83031313e-01, 1.85828640e-01,
#         1.22008703e-01],
#        [7.07070707e-01, 4.99948985e-01, 3.53499282e-01, 2.49948987e-01,
#         1.76731607e-01],
#        [7.57575758e-01, 5.73921028e-01, 4.34788658e-01, 3.29385347e-01,
#         2.49534354e-01],
#        [8.08080808e-01, 6.52994592e-01, 5.27672398e-01, 4.26401938e-01,
#         2.41164465e+03],
#        [4.79797980e+00, 2.30206101e+01, 1.10452422e+02, 5.29948491e+02,
#         2.54268216e+03],
#        [4.84848485e+00, 2.35078053e+01, 1.13977238e+02, 5.52616911e+02,
#         2.67935472e+03],
#        [4.89898990e+00, 2.40001020e+01, 1.17576257e+02, 5.76004897e+02,
#         2.82184217e+03],
#        [4.94949495e+00, 2.44975003e+01, 1.21250254e+02, 6.00127519e+02,
#         2.97032812e+03],
#        [5.00000000e+00, 2.50000000e+01, 1.25000000e+02, 6.25000000e+02,
#         3.12500000e+03]])

# %%
regr_poly = LinearRegression()

# %%
regr_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_poly.predict(X_poly), 'r')

# %%
print('Coefficients: ', regr_poly.coef_)
print('interception: ', regr_poly.intercept_)
# Out:
# Coefficients:  [-0.88406596  1.192837   -0.46279423  0.09083311 -0.00666541]
# interception:  0.9040907858555665

# %%
W=regr_poly.coef_
b=regr_poly.intercept_
np.dot(X_poly,W.T)+b
# Out:
# array([0.90409079, 0.8624246 , 0.82649418, 0.79596276, 0.77050723,
#        0.74981785, 0.73359805, 0.72156411, 0.71344492, 0.70898171,
#        0.70792779, 0.71004831, 0.71511994, 0.72293067, 0.73327951,
#        0.74597625, 0.76084115, 0.77770475, 0.79640754, 0.81679975,
#        0.83874105, 0.8621003 , 0.88675528, 0.91259244, 0.93950665,
#        0.9674009 , 0.99618604, 1.02578057, 1.05611032, 1.0871082 ,
#        1.11871395, 1.15087389, 1.18354062, 1.21667278, 1.25023477,
#        1.28419653, 1.31853322, 1.353225  , 1.38825675, 1.42361781,
#        1.4593017 , 1.49530589, 1.53163152, 1.56828314, 1.60526842,
#        1.64259795, 1.68028492, 1.71834486, 1.75679542, 1.79565607,
#        1.83494785, 1.8746931 , 1.91491521, 1.95563834, 1.99688717,
#        2.03868664, 2.08106167, 2.12403692, 2.16763651, 2.21188376,
#        2.25680092, 2.30240894, 2.34872716, 2.3957731 , 2.44356213,
#        2.49210728, 2.54141892, 2.59150453, 2.64236842, 2.69401149,
#        2.74643092, 2.79961998, 2.8535677 , 2.90825862, 2.96367256,
#        3.01978435, 3.07656352, 3.13397409, 3.19197429, 3.25051629,
#        3.30954595, 3.36900254, 3.4288185 , 3.48891914, 3.54922243,
#        3.60963869, 3.67007036, 3.73041172, 3.7905486 , 3.8503582 ,
#        3.90970873, 3.96845922, 4.02645921, 4.08354851, 4.13955695,
#        4.19430407, 4.24759892, 4.29923973, 4.34901372, 4.39669677])

# %%
regr_poly.predict(X_poly)
# Out:
# array([0.90409079, 0.8624246 , 0.82649418, 0.79596276, 0.77050723,
#        0.74981785, 0.73359805, 0.72156411, 0.71344492, 0.70898171,
#        0.70792779, 0.71004831, 0.71511994, 0.72293067, 0.73327951,
#        0.74597625, 0.76084115, 0.77770475, 0.79640754, 0.81679975,
#        0.83874105, 0.8621003 , 0.88675528, 0.91259244, 0.93950665,
#        0.9674009 , 0.99618604, 1.02578057, 1.05611032, 1.0871082 ,
#        1.11871395, 1.15087389, 1.18354062, 1.21667278, 1.25023477,
#        1.28419653, 1.31853322, 1.353225  , 1.38825675, 1.42361781,
#        1.4593017 , 1.49530589, 1.53163152, 1.56828314, 1.60526842,
#        1.64259795, 1.68028492, 1.71834486, 1.75679542, 1.79565607,
#        1.83494785, 1.8746931 , 1.91491521, 1.95563834, 1.99688717,
#        2.03868664, 2.08106167, 2.12403692, 2.16763651, 2.21188376,
#        2.25680092, 2.30240894, 2.34872716, 2.3957731 , 2.44356213,
#        2.49210728, 2.54141892, 2.59150453, 2.64236842, 2.69401149,
#        2.74643092, 2.79961998, 2.8535677 , 2.90825862, 2.96367256,
#        3.01978435, 3.07656352, 3.13397409, 3.19197429, 3.25051629,
#        3.30954595, 3.36900254, 3.4288185 , 3.48891914, 3.54922243,
#        3.60963869, 3.67007036, 3.73041172, 3.7905486 , 3.8503582 ,
#        3.90970873, 3.96845922, 4.02645921, 4.08354851, 4.13955695,
#        4.19430407, 4.24759892, 4.29923973, 4.34901372, 4.39669677])

# %% [markdown]
# #### RBF
#
# $$\phi_i = e^{-\| x - c_i \|^2/2\sigma^2}$$

# %%
# normal distrubution
def RBF(x, center, sigma):
    k = np.exp(-(x - center)**2/(2*sigma**2))
    return k

# %%
sigma = 0.3

# %%
X_rbf = np.array([[RBF(k, .5, sigma), 
                  RBF(k, 1.5, sigma),
                  RBF(k, 2.5, sigma),
                  RBF(k, 3.5, sigma),
                  RBF(k, 4.5, sigma)] for k in x])

# %%
regr_rbf = LinearRegression()

# %%
regr_rbf.fit(X_rbf, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_rbf.predict(X_rbf), 'r')

# %%
print('Coefficients: ', regr_rbf.coef_)
print('interception: ', regr_rbf.intercept_)
# Out:
# Coefficients:  [-0.79932325 -1.81557342  1.12912355  0.3312077   3.17323816]
# interception:  1.7740239427975046

# %% [markdown]
# #### Comparison

# %%
Y_lin = regr_lin.predict(X)
Y_poly = regr_poly.predict(X_poly)
Y_rbf = regr_rbf.predict(X_rbf)

# %%
plt.scatter(x,y)

plt.plot(x, Y_lin, label='linear')
plt.plot(x, Y_poly, label='polynomial')
plt.plot(x, Y_rbf, label='rbf')
plt.legend()

# %% [markdown]
# ## 請計算模型的MSE

# %%
print(np.sum((regr_lin.predict(X)-y)**2) / len(y))
# Out:
# 0.536630187961624

# %%
print(np.sum((regr_poly.predict(X_poly)-y)**2) / len(y))
# Out:
# 0.4745085361258377

# %%
print(np.sum((regr_rbf.predict(X_rbf)-y)**2) / len(y))
# Out:
# 0.2637030401398331
